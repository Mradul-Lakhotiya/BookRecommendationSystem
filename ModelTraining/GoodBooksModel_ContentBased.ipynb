# %%
import pandas as pd
import ast
import re

# %%
df = pd.read_csv('../Data/GoodReads_100k_books_cleaned.csv')

# %%
def isbn_list_to_book_details(isbn_list, df):
    """
    Function to retrieve book details for a list of ISBNs.
    
    Parameters:
    isbn_list (list): A list of ISBN numbers.
    df (DataFrame): The dataset containing book details.
    
    Returns:
    list: A list of dictionaries with book details for each ISBN in isbn_list.
    """
    books_details = []
    
    for isbn in isbn_list:
        # Search for the book in the DataFrame based on ISBN
        book = df[df['isbn'] == isbn]

        if not book.empty:
            # Extract details from the book
            book_details = {
                'title': book['title'].values[0],
                'author': book['author'].values[0],
                'genre': book['genre'].values[0],  # genre_list is a list of genres
                'rating': book['rating'].values[0],
                'totalratings': book['totalratings'].values[0],
                'isbn': book['isbn'].values[0],
                'pages': book['pages'].values[0],
                'img': book['img'].values[0]
            }
            books_details.append(book_details)
        else:
            books_details.append(f"Book with ISBN {isbn} not found.")
    
    return books_details

# %%
def preprocess_for_content_model(df):
    # 1. Parse genre_list
    def parse_genre_list(val):
        if isinstance(val, list): return val
        if not isinstance(val, str): return []
        try:
            parsed = ast.literal_eval(val)
            if isinstance(parsed, list): return parsed
        except: pass
        s = val.strip().lstrip('[').rstrip(']')
        items = []
        for part in s.split(','):
            item = part.strip().strip("'\" ")
            if item and '...' not in item: items.append(item)
        return items

    # 2. Clean a text field
    def clean_text(x):
        if not isinstance(x, str):
            return ''
        x = x.lower()
        x = re.sub(r'[^\w\s]', ' ', x)
        x = re.sub(r'\s+', ' ', x)
        return x.strip()

    df = df.copy()
    
    # Parse genre
    df['genre_list'] = df['genre_list'].apply(parse_genre_list)
    
    # Clean text fields
    df['title_clean'] = df['title'].apply(clean_text)
    df['author_clean'] = df['author'].apply(clean_text)
    df['desc_clean'] = df['desc'].apply(clean_text)
    df['genres_clean'] = df['genre_list'].apply(lambda genres: ' '.join([clean_text(g) for g in genres]))
    # Combine all into one feature
    df['combined_features'] = df['title_clean'] + ' ' + df['author_clean'] + ' ' + df['desc_clean'] + ' ' + df['genres_clean']

    return df

# %%
df_clean = preprocess_for_content_model(df)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import numpy as np

def build_sparse_similarity(df_clean, top_k=20):
    tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
    tfidf_matrix = tfidf.fit_transform(df_clean['combined_features'])

    # Using NearestNeighbors to get top-k similar items (cosine distance = 1 - similarity)
    model = NearestNeighbors(n_neighbors=top_k + 1, metric='cosine')  # +1 to include self
    model.fit(tfidf_matrix)

    distances, indices = model.kneighbors(tfidf_matrix)

    # Store results in a dictionary: {book_index: [similar_book_indices]}
    similarity_dict = {
        i: [idx for idx in neighbor_list[1:]]  # exclude self at index 0
        for i, neighbor_list in enumerate(indices)
    }

    return similarity_dict

# %%
similarity_matrix = build_sparse_similarity(df_clean)

# %%
def recommend_similar_isbns(isbn, df, similarity_dict):
    if isbn not in df['isbn'].values:
        return []

    idx = df[df['isbn'] == isbn].index[0]

    similar_idxs = similarity_dict.get(idx, [])
    return df.iloc[similar_idxs]['isbn'].tolist()

# %%
recom = recommend_similar_isbns('002914180X', df_clean, similarity_matrix)

# %%
isbn_list_to_book_details(['002914180X'], df_clean)
# Out:
# [{'title': 'Between Two Fires: American Indians in the Civil War',
#   'author': 'Laurence M. Hauptman',
#   'genre': 'History,Military History,Civil War,American History,American Civil War,Nonfiction,North American Hi...,American History,Native Americans',
#   'rating': 3.52,
#   'totalratings': 33,
#   'isbn': '002914180X',
#   'pages': 0,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1387738765l/1001053.jpg'}]

# %%
isbn_list_to_book_details(recom, df_clean)
# Out:
# [{'title': "Chancellorsville: Lee's Greatest Battle",
#   'author': 'Edward J. Stackpole',
#   'genre': 'Military History,Civil War,History,Nonfiction,American History,American Civil War,North American Hi...,American History,American Civil War,Civil War History,Military,Military History',
#   'rating': 3.6,
#   'totalratings': 45,
#   'isbn': '811722384',
#   'pages': 0,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1347720555l/1644548.jpg'},
#  {'title': 'Jeb Stuart: The Last Cavalier',
#   'author': 'Burke Davis',
#   'genre': 'Military History,Civil War,Biography,History,American History,American Civil War,North American Hi...,American History,American Civil War,Civil War History,War,Military Fiction,Nonfiction,War',
#   'rating': 3.94,
#   'totalratings': 170,
#   'isbn': '517185970',
#   'pages': 462,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1387736934l/1083113.jpg'},
#  {'title': 'The Blue and the Gray (2 Vols in 1)',
#   'author': 'Henry Steele Commager',
#   'genre': 'History,Military History,Civil War,American History,American Civil War,Nonfiction,Historical,American Civil War,Civil War History,North American Hi...,American History,War,Military Fiction,War',
#   'rating': 4.02,
#   'totalratings': 98,
#   'isbn': '517060159',
#   'pages': 1248,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1389925966l/1279565.jpg'},
#  {'title': 'Shiloh, 1862',
#   'author': 'Winston Groom',
#   'genre': 'Military History,Civil War,History,Nonfiction,American History,American Civil War,North American Hi...,American History,Military,Military History,War,Military Fiction,War,American Civil War,Civil War Western Theater,American Civil War,Civil War History',
#   'rating': 4.05,
#   'totalratings': 998,
#   'isbn': '142620874X',
#   'pages': 448,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1333580152l/12550172.jpg'},
#  {'title': 'The War for the Union: The Improvised War, 1861-62',
#   'author': 'Allan Nevins',
#   'genre': 'Military History,Civil War,History,American History,American Civil War,North American Hi...,American History,Nonfiction,Military,Military History,War,War,Military Fiction,American Civil War,Civil War History',
#   'rating': 4.47,
#   'totalratings': 51,
#   'isbn': '684104261',
#   'pages': 436,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1391276438l/1064715.jpg'},
#  {'title': 'The Life of Johnny Reb: The Common Soldier of the Confederacy',
#   'author': 'Bell Irvin Wiley',
#   'genre': 'Military History,Civil War,History,American History,American Civil War,North American Hi...,American History,Nonfiction,Military,Military History,War,American Civil War,Civil War History,War,Military Fiction,American Civil War,Civil War Confederacy',
#   'rating': 4.05,
#   'totalratings': 1181,
#   'isbn': '807104752',
#   'pages': 444,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1388459138l/1205819.jpg'},
#  {'title': 'How the North Won: A Military History of the Civil War',
#   'author': 'Herman Hattaway,Archer Jones',
#   'genre': 'Military History,Civil War,History,American History,American Civil War,Nonfiction,War,Military,Military History,War,Military Fiction,North American Hi...,American History,Academic,Grad School,American Civil War,Civil War History',
#   'rating': 4.08,
#   'totalratings': 103,
#   'isbn': '252062108',
#   'pages': 784,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1347672318l/1628534.jpg'},
#  {'title': 'The Civil War: A Visual History',
#   'author': 'D.K. Publishing',
#   'genre': 'History,Military History,Civil War,Nonfiction,War,Reference,North American Hi...,American History,American History,American Civil War,Literature,American,American Civil War,Civil War History,War,Military Fiction',
#   'rating': 4.35,
#   'totalratings': 201,
#   'isbn': '075667185X',
#   'pages': 360,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1347628840l/10430284.jpg'},
#  {'title': 'To Appomattox: Nine April Days, 1865',
#   'author': 'Burke Davis',
#   'genre': 'Military History,Civil War,History,American History,American Civil War,War,War,Military Fiction,Nonfiction,American Civil War,Civil War Eastern Theater,North American Hi...,American History,Military,Military History,American Civil War,Appomattox Campaign',
#   'rating': 3.99,
#   'totalratings': 180,
#   'isbn': '1580800971',
#   'pages': 464,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1347453169l/1051608.jpg'},
#  {'title': 'Gettysburg: The Final Fury',
#   'author': 'Bruce Catton',
#   'genre': 'History,Military History,Civil War,Nonfiction,North American Hi...,American History,American History,American Civil War,War,Military Fiction,Military,Military History,War,American Civil War,Civil War History',
#   'rating': 4.2,
#   'totalratings': 323,
#   'isbn': '385411456',
#   'pages': 114,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1182365092l/1265942.jpg'},
#  {'title': 'Battle Tactics of the Civil War',
#   'author': 'Paddy Griffith',
#   'genre': 'American History,American Civil War,Military History,Civil War,History,Military,Military History,North American Hi...,American History,Nonfiction,War,Military Fiction',
#   'rating': 3.74,
#   'totalratings': 118,
#   'isbn': '300042477',
#   'pages': 240,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1347735245l/1117353.jpg'},
#  {'title': 'Battle Maps of the Civil War (American Heritage)',
#   'author': "Richard O'Shea,David Greenspan,Robert K. Krick",
#   'genre': 'History,Military History,Civil War,Military,Military History,North American Hi...,American History,Nonfiction,American History,American Civil War',
#   'rating': 4.09,
#   'totalratings': 23,
#   'isbn': '933031718',
#   'pages': 176,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1172163784l/144489._SX318_.jpg'},
#  {'title': 'Hallowed Ground: A Walk at Gettysburg',
#   'author': 'James M. McPherson',
#   'genre': 'History,Military History,Civil War,Nonfiction,North American Hi...,American History,Travel,American History,American Civil War,War,Military,Military History,Historical,American Civil War,Civil War History',
#   'rating': 4.18,
#   'totalratings': 1552,
#   'isbn': '609610236',
#   'pages': 144,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1426983418l/101646.jpg'},
#  {'title': 'Chattanooga: A Death Grip on the Confederacy',
#   'author': 'James Lee McDonough',
#   'genre': 'Military History,Civil War,American History,American Civil War,History,American Civil War,Civil War Western Theater,Nonfiction,Military,Military History',
#   'rating': 3.97,
#   'totalratings': 30,
#   'isbn': '870494252',
#   'pages': 298,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1451411861l/1283548.jpg'},
#  {'title': 'Richmond Redeemed: The Siege at Petersburg',
#   'author': 'Richard J. Sommers',
#   'genre': 'Military History,Civil War,American History,American Civil War,American Civil War,Civil War Eastern Theater,History,American Civil War,Siege Of Petersburg,North American Hi...,American History',
#   'rating': 4.14,
#   'totalratings': 22,
#   'isbn': '038515626X',
#   'pages': 670,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1334254112l/1619831.jpg'},
#  {'title': 'Sea of Gray: The Around-The-World Odyssey of the Confederate Raider Shenandoah',
#   'author': 'Tom Chaffin',
#   'genre': 'History,Military History,Civil War,Nonfiction,American History,American Civil War,North American Hi...,American History,War,Military History,Naval History',
#   'rating': 3.8,
#   'totalratings': 265,
#   'isbn': '809095114',
#   'pages': 432,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1312063026l/1104596.jpg'},
#  {'title': 'The Barefoot Brigade',
#   'author': 'Douglas C. Jones',
#   'genre': 'Historical,Historical Fiction,Military History,Civil War,Fiction,War,American History,American Civil War,North American Hi...,American History,Historical,War,Military Fiction',
#   'rating': 4.15,
#   'totalratings': 95,
#   'isbn': '30600413',
#   'pages': 313,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1373813165l/1713894.jpg'},
#  {'title': 'The Bloodiest Day: The Battle of Antietam',
#   'author': 'Ronald H. Bailey',
#   'genre': 'Military History,Civil War,History,American History,American Civil War,Nonfiction,Military,Military History,American Civil War,Civil War Eastern Theater,American Civil War,Antietam Campaign',
#   'rating': 3.86,
#   'totalratings': 85,
#   'isbn': '809447401',
#   'pages': 176,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1546724271l/1720694._SX318_.jpg'},
#  {'title': 'The Revolution of 1861: The American Civil War in the Age of Nationalist Conflict',
#   'author': 'Andre Fleche',
#   'genre': 'History,North American Hi...,American History,Military History,Civil War,American History,American Civil War,Nonfiction',
#   'rating': 3.86,
#   'totalratings': 35,
#   'isbn': '807835234',
#   'pages': 204,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1438534479l/13557252.jpg'},
#  {'title': 'This Hallowed Ground: The Story of the Union Side of the Civil War',
#   'author': 'Bruce Catton,Lewis Gannett',
#   'genre': 'History,Military History,Civil War,Nonfiction,American History,American Civil War,North American Hi...,American History,Military,Military History,War,Military Fiction,War,Historical,American Civil War,Civil War History',
#   'rating': 4.33,
#   'totalratings': 987,
#   'isbn': '078581552X',
#   'pages': 448,
#   'img': 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1348361307l/101648.jpg'}]

# %%
import ast
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# %%
class ContentBasedRecommender:
    def __init__(self, df, top_k=20):
        self.df_original = df.copy()
        self.top_k = top_k
        self.df_clean = self._preprocess(df)
        self.similarity_dict = self._build_sparse_similarity()

    def _parse_genre_list(self, val):
        if isinstance(val, list): return val
        if not isinstance(val, str): return []
        try:
            parsed = ast.literal_eval(val)
            if isinstance(parsed, list): return parsed
        except: pass
        s = val.strip().lstrip('[').rstrip(']')
        items = []
        for part in s.split(','):
            item = part.strip().strip("'\" ")
            if item and '...' not in item: items.append(item)
        return items

    def _clean_text(self, x):
        if not isinstance(x, str):
            return ''
        x = x.lower()
        x = re.sub(r'[^\w\s]', ' ', x)
        x = re.sub(r'\s+', ' ', x)
        return x.strip()

    def _preprocess(self, df):
        df = df.copy()

        # Clean and extract features
        df['genre_list'] = df['genre_list'].apply(self._parse_genre_list)
        df['title_clean'] = df['title'].apply(self._clean_text)
        df['author_clean'] = df['author'].apply(self._clean_text)
        df['desc_clean'] = df['desc'].apply(self._clean_text)
        df['genres_clean'] = df['genre_list'].apply(
            lambda genres: ' '.join([self._clean_text(g) for g in genres])
        )

        df['combined_features'] = (
            df['title_clean'] + ' ' +
            df['author_clean'] + ' ' +
            df['desc_clean'] + ' ' +
            df['genres_clean']
        )
        return df

    def _build_sparse_similarity(self):
        tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
        tfidf_matrix = tfidf.fit_transform(self.df_clean['combined_features'])

        model = NearestNeighbors(n_neighbors=self.top_k + 1, metric='cosine')
        model.fit(tfidf_matrix)

        distances, indices = model.kneighbors(tfidf_matrix)

        similarity_dict = {
            i: [idx for idx in neighbor_list[1:]]
            for i, neighbor_list in enumerate(indices)
        }
        return similarity_dict

    def recommend_by_isbn(self, isbn):
        if isbn not in self.df_clean['isbn'].values:
            return []

        idx = self.df_clean[self.df_clean['isbn'] == isbn].index[0]
        similar_idxs = self.similarity_dict.get(idx, [])
        return self.df_clean.iloc[similar_idxs]['isbn'].tolist()

# %%
import ast
import re
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import pickle
from scipy.sparse import save_npz, load_npz

class ContentBasedRecommender:
    def __init__(self, top_k=20):
        self.top_k = top_k
        self.vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
        self.model = NearestNeighbors(n_neighbors=top_k + 1, metric='cosine')
        self.similarity_dict = {}
        self.df_clean = None
        self.tfidf_matrix = None

    def _parse_genre_list(self, val):
        if isinstance(val, list): return val
        if not isinstance(val, str): return []
        try:
            parsed = ast.literal_eval(val)
            if isinstance(parsed, list): return parsed
        except: pass
        s = val.strip().lstrip('[').rstrip(']')
        items = []
        for part in s.split(','):
            item = part.strip().strip("'\" ")
            if item and '...' not in item: items.append(item)
        return items

    def _clean_text(self, x):
        if not isinstance(x, str): return ''
        x = x.lower()
        x = re.sub(r'[^\w\s]', ' ', x)
        x = re.sub(r'\s+', ' ', x)
        return x.strip()

    def preprocess(self, df):
        df = df.copy()
        df['genre_list'] = df['genre_list'].apply(self._parse_genre_list)
        df['title_clean'] = df['title'].apply(self._clean_text)
        df['author_clean'] = df['author'].apply(self._clean_text)
        df['desc_clean'] = df['desc'].apply(self._clean_text)
        df['genres_clean'] = df['genre_list'].apply(lambda genres: ' '.join([self._clean_text(g) for g in genres]))
        df['combined_features'] = df['title_clean'] + ' ' + df['author_clean'] + ' ' + df['desc_clean'] + ' ' + df['genres_clean']
        self.df_clean = df
        return df

    def build_similarity(self):
        tfidf_matrix = self.vectorizer.fit_transform(self.df_clean['combined_features'])
        self.tfidf_matrix = tfidf_matrix
        self.model.fit(tfidf_matrix)

        distances, indices = self.model.kneighbors(tfidf_matrix)
        self.similarity_dict = {
            i: [idx for idx in neighbors[1:]]  # skip self
            for i, neighbors in enumerate(indices)
        }

    def recommend_by_isbn(self, isbn):
        if isbn not in self.df_clean['isbn'].values:
            return []
        idx = self.df_clean[self.df_clean['isbn'] == isbn].index[0]
        similar_idxs = self.similarity_dict.get(idx, [])
        return self.df_clean.iloc[similar_idxs]['isbn'].tolist()

    def save(self, path_prefix):
        columns_to_keep = ['isbn', 'title_clean', 'author_clean', 'desc_clean', 'genres_clean', 'combined_features']
        self.df_clean = self.df_clean[columns_to_keep]
        
        with open(f'{path_prefix}_vectorizer.pkl', 'wb') as f:
            pickle.dump(self.vectorizer, f)
        with open(f'{path_prefix}_model.pkl', 'wb') as f:
            pickle.dump(self.model, f)
        with open(f'{path_prefix}_similarity_dict.pkl', 'wb') as f:
            pickle.dump(self.similarity_dict, f)
        self.df_clean.to_csv(f'{path_prefix}_df_clean.csv', index=False)
        save_npz(f'{path_prefix}_tfidf_matrix.npz', self.tfidf_matrix)

    def load(self, path_prefix):
        with open(f'{path_prefix}_vectorizer.pkl', 'rb') as f:
            self.vectorizer = pickle.load(f)
        with open(f'{path_prefix}_model.pkl', 'rb') as f:
            self.model = pickle.load(f)
        with open(f'{path_prefix}_similarity_dict.pkl', 'rb') as f:
            self.similarity_dict = pickle.load(f)
        self.df_clean = pd.read_csv(f'{path_prefix}_df_clean.csv')
        self.tfidf_matrix = load_npz(f'{path_prefix}_tfidf_matrix.npz')

# %%
import os

recommender = ContentBasedRecommender(top_k=20)
df_clean = recommender.preprocess(df)
recommender.build_similarity()

# %%
recommender.save("model_assets/book_recommender")

# %%
# Later, or in deployment:
new_recommender = ContentBasedRecommender()
new_recommender.load("model_assets/book_recommender")
recommendations = new_recommender.recommend_by_isbn("123456789X")

# %%
recommendations
# Out:
# []

# %%
import ast
import re
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
import pickle
from scipy.sparse import save_npz, load_npz

class ContentBasedRecommender:
    def __init__(self, top_k=20):
        self.top_k = top_k
        self.vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
        self.model = NearestNeighbors(n_neighbors=top_k + 1, metric='cosine')
        self.similarity_dict = {}
        self.df_clean = None
        self.tfidf_matrix = None

    def _parse_genre_list(self, val):
        if isinstance(val, list): return val
        if not isinstance(val, str): return []
        try:
            parsed = ast.literal_eval(val)
            if isinstance(parsed, list): return parsed
        except: pass
        s = val.strip().lstrip('[').rstrip(']')
        items = []
        for part in s.split(','):
            item = part.strip().strip("'\" ")
            if item and '...' not in item: items.append(item)
        return items

    def _clean_text(self, x):
        if not isinstance(x, str): return ''
        x = x.lower()
        x = re.sub(r'[^\w\s]', ' ', x)
        x = re.sub(r'\s+', ' ', x)
        return x.strip()

    def preprocess(self, df):
        # Check if necessary columns exist
        required_columns = ['title', 'author', 'desc', 'genre_list']
        for col in required_columns:
            if col not in df.columns:
                raise ValueError(f"Missing required column: {col}")
        
        df = df.copy()
        df['genre_list'] = df['genre_list'].apply(self._parse_genre_list)
        df['title_clean'] = df['title'].apply(self._clean_text)
        df['author_clean'] = df['author'].apply(self._clean_text)
        df['desc_clean'] = df['desc'].apply(self._clean_text)
        df['genres_clean'] = df['genre_list'].apply(lambda genres: ' '.join([self._clean_text(g) for g in genres]))
        df['combined_features'] = df['title_clean'] + ' ' + df['author_clean'] + ' ' + df['desc_clean'] + ' ' + df['genres_clean']
        self.df_clean = df
        return df

    def build_similarity(self):
        if self.df_clean is None:
            raise ValueError("Dataframe is not preprocessed. Call preprocess() first.")
        
        tfidf_matrix = self.vectorizer.fit_transform(self.df_clean['combined_features'])
        self.tfidf_matrix = tfidf_matrix
        self.model.fit(tfidf_matrix)

        distances, indices = self.model.kneighbors(tfidf_matrix)
        self.similarity_dict = {
            i: [idx for idx in neighbors[1:]]  # skip self
            for i, neighbors in enumerate(indices)
        }

    def recommend_by_isbn(self, isbn):
        if isbn not in self.df_clean['isbn'].values:
            return []
        idx = self.df_clean[self.df_clean['isbn'] == isbn].index[0]
        similar_idxs = self.similarity_dict.get(idx, [])
        return self.df_clean.iloc[similar_idxs]['isbn'].tolist()

    def save(self, path_prefix):
        columns_to_keep = ['isbn', 'title_clean', 'author_clean', 'desc_clean', 'genres_clean', 'combined_features']
        self.df_clean = self.df_clean[columns_to_keep]
        
        # Save vectorizer, model, similarity_dict, and tfidf_matrix to files
        with open(f'{path_prefix}_vectorizer.pkl', 'wb') as f:
            pickle.dump(self.vectorizer, f)
        with open(f'{path_prefix}_model.pkl', 'wb') as f:
            pickle.dump(self.model, f)
        with open(f'{path_prefix}_similarity_dict.pkl', 'wb') as f:
            pickle.dump(self.similarity_dict, f)
        self.df_clean.to_csv(f'{path_prefix}_df_clean.csv', index=False)
        save_npz(f'{path_prefix}_tfidf_matrix.npz', self.tfidf_matrix)

    def load(self, path_prefix):
        # Load vectorizer, model, similarity_dict, and tfidf_matrix from files
        with open(f'{path_prefix}_vectorizer.pkl', 'rb') as f:
            self.vectorizer = pickle.load(f)
        with open(f'{path_prefix}_model.pkl', 'rb') as f:
            self.model = pickle.load(f)
        with open(f'{path_prefix}_similarity_dict.pkl', 'rb') as f:
            self.similarity_dict = pickle.load(f)
        self.df_clean = pd.read_csv(f'{path_prefix}_df_clean.csv')
        self.tfidf_matrix = load_npz(f'{path_prefix}_tfidf_matrix.npz')

# %%
df = pd.read_csv("../Data/GoodReads_100k_books_cleaned.csv")

# %%
# Initialize the recommender
recommender = ContentBasedRecommender()

# Preprocess the dataframe (assuming `df` is your DataFrame)
recommender.preprocess(df)

# Build the similarity model
recommender.build_similarity()

# Recommend books similar to a specific ISBN
isbn = '002914180X'
recommendations = recommender.recommend_by_isbn(isbn)
print(f"Recommendations for ISBN {isbn}: {recommendations}")

# Save the model and data
recommender.save('model_assets/book_recommender')
# Out:
# Recommendations for ISBN 002914180X: ['811722384', '517185970', '142620874X', '517060159', '684104261', '807104752', '252062108', '075667185X', '1580800971', '385411456', '300042477', '933031718', '609610236', '870494252', '038515626X', '809095114', '30600413', '809447401', '078581552X', '807835234']

# %%
# Load the model and data
new_recommender = ContentBasedRecommender()

new_recommender.load('model_assets/book_recommender')
isbn = '002914180X'
# Get recommendations again after loading
recommendations = recommender.recommend_by_isbn(isbn)
print(f"Recommendations after loading for ISBN {isbn}: {recommendations}")
# Out:
# Recommendations after loading for ISBN 002914180X: ['811722384', '517185970', '142620874X', '517060159', '684104261', '807104752', '252062108', '075667185X', '1580800971', '385411456', '300042477', '933031718', '609610236', '870494252', '038515626X', '809095114', '30600413', '809447401', '078581552X', '807835234']

# %%
recommendations = recommender.recommend_by_isbn(isbn)
print(f"Recommendations after loading for ISBN {isbn}: {recommendations}")
# Out:
# Recommendations after loading for ISBN 002914180X: ['811722384', '517185970', '142620874X', '517060159', '684104261', '807104752', '252062108', '075667185X', '1580800971', '385411456', '300042477', '933031718', '609610236', '870494252', '038515626X', '809095114', '30600413', '809447401', '078581552X', '807835234']

# %%
Recommendations after loading for ISBN 002914180X: ['811722384', '517185970', '517060159', '142620874X', '684104261', '807104752', '252062108', '075667185X', '1580800971', '385411456', '300042477', '933031718', '609610236', '870494252', '038515626X', '809095114', '30600413', '809447401', '807835234', '078581552X']
